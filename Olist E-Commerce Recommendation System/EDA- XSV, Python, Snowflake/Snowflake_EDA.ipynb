# %% [markdown]
# # Snowflake_EDA

# %%
import pandas as pd

# %% [markdown]
# Reading the dataset using Pandas

# %%
df1 = pd.read_csv('/home/sanket/project/olist/olist_customers_dataset.csv')
df2 = pd.read_csv('/home/sanket/project/olist/olist_geolocation_dataset.csv')
df3 = pd.read_csv('/home/sanket/project/olist/olist_order_items_dataset.csv')
df4 = pd.read_csv('/home/sanket/project/olist/olist_order_payments_dataset.csv')
df5 = pd.read_csv('/home/sanket/project/olist/olist_order_reviews_dataset.csv')
df6 = pd.read_csv('/home/sanket/project/olist/olist_orders_dataset.csv')
df7 = pd.read_csv('/home/sanket/project/olist/olist_products_dataset.csv')
df8 = pd.read_csv('/home/sanket/project/olist/olist_sellers_dataset.csv')
df9 = pd.read_csv('/home/sanket/project/olist/product_category_name_translation.csv')

# %%
a= [df1,df2,df3,df4,df5,df6,df7,df8,df9]

# %% [markdown]
# Iterating Through the Dataset, Renaming the Columns in order to match the column name convention with Snowflake

# %%
for df in a:
    print("\n Next \n")
    #print(df[df.isnull().any(axis=1)])
    print("\n")
    #print(df.isnull().sum())
    print("\n duplicated\n")
    df.drop_duplicates()
    print(df[df.duplicated()])
    df.columns = df.columns.str.upper()
    print(df.head())
    #print(df.dtype)
# Out:
#  Next
#
#
#
#
#  duplicated
#
# Empty DataFrame
# Columns: [customer_id, customer_unique_id, customer_zip_code_prefix, customer_city, customer_state]
# Index: []
#                         CUSTOMER_ID                CUSTOMER_UNIQUE_ID  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    CUSTOMER_ZIP_CODE_PREFIX          CUSTOMER_CITY CUSTOMER_STATE
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# ...

# %%
import snowflake.connector
from snowflake.sqlalchemy import URL
from sqlalchemy import create_engine

# %%
import snowflake.connector as snow
from snowflake.connector.pandas_tools import write_pandas

# %%
conn = snow.connect(user='', # Credentials Masked
   password='',
   account='',
   # (the prefix in your snowflake space... for example, 
   # company.snowflakecomputing.com would just be "company" as the ACCOUNT name)
    warehouse='Compute_WH',
    database='OLIST',
    schema='PUBLIC')
                    
cur = conn.cursor()
cur.close()
#original = "customer_transaction_data_pre_processed.csv" 
#delimiter = ","
#total = pd.read_csv(original, sep = delimiter)
for df in a:
    write_pandas(conn, df, str(df.upper()))
    cur = conn.cursor()                
    sql = "ALTER WAREHOUSE Compute_WH SUSPEND"
    cur.execute(sql)
    cur.close()
conn.close()
