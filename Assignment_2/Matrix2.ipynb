# %%
import pandas as pd
#!pip install pandasql
import pandasql as ps

# %%
ip = pd.read_csv (r'C:\Users\ajink\Documents\Ajinkya\ADM\input_part2.csv') 
print (ip)
# Out:
#     Sr.No                                            Reviews R/ F
# 0     399  Such a stupid hotel, I wont recommend it if yo...    F
# 1     331  Missing information on how to use it, stupid b...    F
# 2      63  I attended my company party at the Trump Inter...    F
# 3      64  Great service, great parking, great food. The ...    F
# 4      65  Perfect place to break up the drive. Enjoy the...    F
# 5      66  Everything was literal perfection! The staff w...    F
# 6      67  From the time I stepped through the door I fel...    F
# 7      68  We had a wonderful stay at The Trump Internati...    F
# 8      69  Stayed here for a concert. Hotel is walking di...    F
# 9      70  Enjoyed a lovely stay at the Trump Internation...    F
# 10     71  Beware of HIDDEN FEES! I stayed 2 nights in th...    F
# 11     76  HORRIBLE SERVICE: I am trying to reach the cor...    F
# 12     84  The Millennium Broadway Hotel is in a great lo...    F
# ...

# %%
mturkresults = pd.read_csv (r'C:\Users\ajink\Downloads\Batch_4601730_batch_results.csv') 
mturkresults = mturkresults.iloc[:,-4:-2]
print (mturkresults)
# Out:
#                                         Input.Reviews  \
# 0   Such a stupid hotel, I wont recommend it if yo...
# 1   Such a stupid hotel, I wont recommend it if yo...
# 2   Such a stupid hotel, I wont recommend it if yo...
# 3   Missing information on how to use it, stupid b...
# 4   Missing information on how to use it, stupid b...
# 5   Missing information on how to use it, stupid b...
# 6   I attended my company party at the Trump Inter...
# 7   I attended my company party at the Trump Inter...
# 8   I attended my company party at the Trump Inter...
# 9   Great service, great parking, great food. The ...
# 10  Great service, great parking, great food. The ...
# 11  Great service, great parking, great food. The ...
# 12  Perfect place to break up the drive. Enjoy the...
# 13  Perfect place to break up the drive. Enjoy the...
# 14  Perfect place to break up the drive. Enjoy the...
# 15  Everything was literal perfection! The staff w...
# ...

# %%
lst = []

for i in ip['Reviews']:
    
    df = mturkresults[mturkresults['Input.Reviews'] == i]
    a=0
    
    for j in df['Answer.Review analysis .label']:
        
        if j == 'Offensive':
            a = a + 1;
    if a > 1:
        lst.extend(['Not Publish', 'Not Publish', 'Not Publish'])
    else:
        lst.extend(['Publish', 'Publish', 'Publish'])
            
print(lst)
# Out:
# ['Not Publish', 'Not Publish', 'Not Publish', 'Publish', 'Publish', 'Publish', 'Not Publish', 'Not Publish', 'Not Publish', 'Publish', 'Publish', 'Publish', 'Publish', 'Publish', 'Publish', 'Publish', 'Publish', 'Publish', 'Publish', 'Publish', 'Publish', 'Publish', 'Publish', 'Publish', 'Publish', 'Publish', 'Publish', 'Publish', 'Publish', 'Publish', 'Publish', 'Publish', 'Publish', 'Publish', 'Publish', 'Publish', 'Publish', 'Publish', 'Publish', 'Publish', 'Publish', 'Publish', 'Publish', 'Publish', 'Publish']

# %%
mturkresults['Input.Label'] = lst
mturkresults
# Out:
#                                         Input.Reviews  \
# 0   Such a stupid hotel, I wont recommend it if yo...
# 1   Such a stupid hotel, I wont recommend it if yo...
# 2   Such a stupid hotel, I wont recommend it if yo...
# 3   Missing information on how to use it, stupid b...
# 4   Missing information on how to use it, stupid b...
# 5   Missing information on how to use it, stupid b...
# 6   I attended my company party at the Trump Inter...
# 7   I attended my company party at the Trump Inter...
# 8   I attended my company party at the Trump Inter...
# 9   Great service, great parking, great food. The ...
# 10  Great service, great parking, great food. The ...
# 11  Great service, great parking, great food. The ...
# 12  Perfect place to break up the drive. Enjoy the...
# 13  Perfect place to break up the drive. Enjoy the...
# 14  Perfect place to break up the drive. Enjoy the...
# 15  Everything was literal perfection! The staff w...
# ...

# %%
mturkresults.to_csv(r'C:\Users\ajink\Downloads\mturkresults_processed.csv',index=False)

# %%
mturkresults['Input.Reviews']
# Out:
# 0     Such a stupid hotel, I wont recommend it if yo...
# 1     Such a stupid hotel, I wont recommend it if yo...
# 2     Such a stupid hotel, I wont recommend it if yo...
# 3     Missing information on how to use it, stupid b...
# 4     Missing information on how to use it, stupid b...
# 5     Missing information on how to use it, stupid b...
# 6     I attended my company party at the Trump Inter...
# 7     I attended my company party at the Trump Inter...
# 8     I attended my company party at the Trump Inter...
# 9     Great service, great parking, great food. The ...
# 10    Great service, great parking, great food. The ...
# 11    Great service, great parking, great food. The ...
# 12    Perfect place to break up the drive. Enjoy the...
# 13    Perfect place to break up the drive. Enjoy the...
# 14    Perfect place to break up the drive. Enjoy the...
# 15    Everything was literal perfection! The staff w...
# 16    Everything was literal perfection! The staff w...
# ...

# %%
# Out:
# ['Not Publish', 'Not Publish', 'Not Publish', 'Publish', 'Publish', 'Publish', 'Not Publish', 'Not Publish', 'Not Publish', 'Publish', 'Publish', 'Publish', 'Publish', 'Publish', 'Publish', 'Publish', 'Publish', 'Publish', 'Publish', 'Publish', 'Publish', 'Publish', 'Publish', 'Publish', 'Publish', 'Publish', 'Publish', 'Publish', 'Publish', 'Publish', 'Publish', 'Publish', 'Publish', 'Publish', 'Publish', 'Publish', 'Publish', 'Publish', 'Publish', 'Publish', 'Publish', 'Publish', 'Publish', 'Publish', 'Publish']

# %%
ans = ps.sqldf("select count(*) as a from df group by df.'Input.Reviews' having df.'Answer.Review analysis .label'='Offensive' ")
